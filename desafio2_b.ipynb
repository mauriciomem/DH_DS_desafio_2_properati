# %%
import pandas as pd
import numpy as np
import re
import random
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
data_location = 'https://github.com/DHDSDesafios/DH_DS_desafio_2_properati/raw/master/data/properatid2caba.zip'
data = pd.read_csv(data_location, compression='zip', encoding="utf-8")

# %%
list(data)
# Out:
# ['Id_caso',
#  'property_type',
#  'place_with_parent_names',
#  'country_name',
#  'state_name',
#  'lat-lon',
#  'lat',
#  'lon',
#  'price',
#  'currency',
#  'price_aprox_local_currency',
#  'price_aprox_usd',
#  'floor',
#  'rooms',
#  'expenses',
#  'description',
#  'title',
#  'Pais',
#  'Zona',
#  'Partido_barrio',
#  'Localidad',
#  'Obs_localidad',
#  'place_name',
#  'geonames_id',
#  'price_usd_per_m2',
#  'price_per_m2',
#  'surface_total_in_m2',
#  'surface_covered_in_m2',
#  'cochera',
#  'piscina',
#  'parrilla',
#  'baulera',
#  'balcon',
#  'terraza',
#  'jardin',
#  'lavadero',
#  'subte',
#  'seguridad',
#  'metrobus']

# %%
data.shape
# Out:
# (29380, 39)

# %%
def datosCol(col=None):
    try:
        if col.dtype != object:
            return {
                    'nombre': col.name,
                    'series_dt': col.dtype,
                    'nulos': int(len(col) - col.describe()[0]), 
                    'nulos_porcentaje': round(col.isnull().sum() / col.size*100, 2),
                    'unicos': int(len(col.value_counts())),
                    'mas_repetido': col.value_counts().index[0],
                    'minimo': round(col.min(), 2),
                    'maximo': round(col.max(), 2),
                    'media': round(col.describe()[1], 2),
                    'mediana': col.median(),
                    'desvio': round(col.describe()[2], 2),
                    'q25': col.describe()[4],
                    'q50': col.describe()[5],
                    'q75': col.describe()[6],
                    'values_dt': [x for x in col.apply(lambda x: type(x)).value_counts().index]
                   }
        else:
            return {
                    'nombre': col.name,
                    'series_dt': col.dtype,
                    'nulos': col.isnull().sum(),
                    'nulos_porcentaje': round(col.isnull().sum() / col.size*100, 2),
                    'unicos': int(col.describe()[1]), 
                    'mas_repetido': col.describe()[2],
                    'nulos': col.isnull().sum(),
                    'frecuencia': int(col.describe()[3]),
                    'values_dt': [x for x in col.apply(lambda x: type(x)).value_counts().index]
                   }
    except:
        return 'use a valid pandas Series'

# %%
data_info = pd.DataFrame([datosCol(data[x]) for x in ['property_type', 'place_name', 'price_aprox_usd', 'floor', 'rooms',
                                                      'price_usd_per_m2', 'price_per_m2', 'surface_total_in_m2',
                                                      'surface_covered_in_m2', 'cochera', 'piscina', 'parrilla', 'baulera',
                                                      'balcon', 'terraza', 'jardin', 'lavadero'] ])
data_info
# Out:
#                    nombre series_dt  nulos  nulos_porcentaje  unicos  \
# 0           property_type    object      0              0.00       4
# 1              place_name    object      0              0.00      62
# 2         price_aprox_usd   float64   1532              5.21    5237
# 3                   floor   float64  26480             90.13      82
# 4                   rooms   float64  11341             38.60      17
# 5        price_usd_per_m2   float64   7227             24.60   10452
# 6            price_per_m2   float64   2512              8.55   12115
# 7     surface_total_in_m2   float64   3638             12.38     734
# 8   surface_covered_in_m2   float64   1170              3.98     620
# 9                 cochera   float64  19299             65.69       1
# 10                piscina   float64  22686             77.22       1
# 11               parrilla   float64  21319             72.56       1
# 12                baulera   float64  24951             84.93       1
# 13                 balcon    object  20458             69.63       4
# 14                terraza   float64  21601             73.52       1
# 15                 jardin   float64  28347             96.48       1
# 16               lavadero   float64  21547             73.34       1
#
#    mas_repetido  frecuencia                         values_dt   minimo  \
# 0     apartment     24713.0                   [<class 'str'>]      NaN
# 1      Belgrano      2745.0                   [<class 'str'>]      NaN
# 2        120000         NaN                 [<class 'float'>]  5103.61
# 3             1         NaN                 [<class 'float'>]     1.00
# 4             2         NaN                 [<class 'float'>]     1.00
# 5          2500         NaN                 [<class 'float'>]    13.80
# 6          2500         NaN                 [<class 'float'>]     3.21
# 7            40         NaN                 [<class 'float'>]     0.00
# 8            30         NaN                 [<class 'float'>]     0.00
# 9             1         NaN                 [<class 'float'>]     1.00
# 10            1         NaN                 [<class 'float'>]     1.00
# 11            1         NaN                 [<class 'float'>]     1.00
# 12            1         NaN                 [<class 'float'>]     1.00
# 13            1      5082.0  [<class 'float'>, <class 'str'>]      NaN
# 14            1         NaN                 [<class 'float'>]     1.00
# 15            1         NaN                 [<class 'float'>]     1.00
# 16            1         NaN                 [<class 'float'>]     1.00
#
#          maximo      media    mediana     desvio         q25        q50  \
# 0           NaN        NaN        NaN        NaN         NaN        NaN
# 1           NaN        NaN        NaN        NaN         NaN        NaN
# 2   46545445.00  263567.97  155000.00  452774.30  104724.465  155000.00
# 3       2509.00      12.64       4.00      83.22       2.000       4.00
# 4         22.00       2.55       2.00       1.47       1.000       2.00
# 5     206333.33    3146.57    2486.41    3722.99    1988.950    2486.41
# 6    2600000.00    3839.77    2727.27   18864.14    2177.420    2727.27
# 7     200000.00     116.88      62.00    1268.88      42.000      62.00
# 8      10958.00      91.43      55.00     203.58      38.000      55.00
# 9          1.00       1.00       1.00       0.00       1.000       1.00
# 10         1.00       1.00       1.00       0.00       1.000       1.00
# 11         1.00       1.00       1.00       0.00       1.000       1.00
# 12         1.00       1.00       1.00       0.00       1.000       1.00
# 13          NaN        NaN        NaN        NaN         NaN        NaN
# 14         1.00       1.00       1.00       0.00       1.000       1.00
# 15         1.00       1.00       1.00       0.00       1.000       1.00
# 16         1.00       1.00       1.00       0.00       1.000       1.00
#
#           q75
# 0         NaN
# 1         NaN
# 2   278000.00
# 3        7.00
# 4        3.00
# 5     3094.27
# 6     3440.00
# 7      110.00
# 8       95.00
# 9        1.00
# 10       1.00
# 11       1.00
# 12       1.00
# 13        NaN
# 14       1.00
# 15       1.00
# 16       1.00

# %%
sns.set_style("darkgrid")
fig, axs = plt.subplots(2,2,figsize=(20,10))
fig.suptitle('Distribuciones sin aplicacion de outliers')

sns.boxplot(x='price_usd_per_m2', data=data, ax=axs[0,1])
axs[0,1].set(xlabel='Precio por metro cuadrado en dolares')

sns.boxplot(x='surface_total_in_m2', data=data, ax=axs[1,0])
axs[1,0].set(xlabel='Superfice total')

plt.show()

# %%
data.loc[data.cochera.isnull(), 'cochera'] = 0
data.cochera.astype('uint8')

data.loc[data.piscina.isnull(), 'piscina'] = 0
data.piscina.astype('uint8')

data.loc[data.parrilla.isnull(), 'parrilla'] = 0
data.parrilla.astype('uint8')

data.loc[data.baulera.isnull(), 'baulera'] = 0
data.baulera.astype('uint8')

data.loc[data.balcon == 'Balcon', 'balcon'] = 1
data.loc[data.balcon == 'BALCON', 'balcon'] = 1
data.loc[data.balcon == 'balcon', 'balcon'] = 1
data.loc[data.balcon.isnull(), 'balcon'] = 0
data.balcon.astype('uint8')

data.loc[data.terraza.isnull(), 'terraza'] = 0
data.terraza.astype('uint8')

data.loc[data.jardin.isnull(), 'jardin'] = 0
data.jardin.astype('uint8')

data.loc[data.lavadero.isnull(), 'lavadero'] = 0
data.lavadero.astype('uint8')

data.loc[data.subte.isnull(), 'subte'] = 0
data.subte.astype('uint8')

data.loc[data.seguridad.isnull(), 'seguridad'] = 0
data.seguridad.astype('uint8')

data.loc[data.metrobus.isnull(), 'metrobus'] = 0
data.metrobus.astype('uint8')
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 29375    0
# 29376    0
# 29377    0
# 29378    0
# 29379    0
# Name: metrobus, Length: 29380, dtype: uint8

# %%
property_type_dummies = pd.get_dummies(data.property_type, prefix='prop_type', drop_first = True)
data = pd.concat([data, property_type_dummies], axis=1)

# %%
place_name_dummies = pd.get_dummies(data.place_name, prefix='pn', drop_first = True)
data = pd.concat([data, place_name_dummies], axis=1)

# %%
list(data)
# Out:
# ['Id_caso',
#  'property_type',
#  'place_with_parent_names',
#  'country_name',
#  'state_name',
#  'lat-lon',
#  'lat',
#  'lon',
#  'price',
#  'currency',
#  'price_aprox_local_currency',
#  'price_aprox_usd',
#  'floor',
#  'rooms',
#  'expenses',
#  'description',
#  'title',
#  'Pais',
#  'Zona',
#  'Partido_barrio',
#  'Localidad',
#  'Obs_localidad',
#  'place_name',
#  'geonames_id',
#  'price_usd_per_m2',
#  'price_per_m2',
#  'surface_total_in_m2',
#  'surface_covered_in_m2',
#  'cochera',
#  'piscina',
#  'parrilla',
#  'baulera',
#  'balcon',
#  'terraza',
#  'jardin',
#  'lavadero',
#  'subte',
#  'seguridad',
#  'metrobus',
#  'prop_type_apartment',
#  'prop_type_house',
#  'prop_type_store',
#  'pn_Agronomía',
#  'pn_Almagro',
#  'pn_Balvanera',
#  'pn_Barracas',
#  'pn_Barrio Norte',
#  'pn_Belgrano',
#  'pn_Boca',
#  'pn_Boedo',
#  'pn_Caballito',
#  'pn_Capital Federal',
#  'pn_Catalinas',
#  'pn_Centro / Microcentro',
#  'pn_Chacarita',
#  'pn_Coghlan',
#  'pn_Colegiales',
#  'pn_Congreso',
#  'pn_Constitución',
#  'pn_Flores',
#  'pn_Floresta',
#  'pn_Las Cañitas',
#  'pn_Liniers',
#  'pn_Mataderos',
#  'pn_Monserrat',
#  'pn_Monte Castro',
#  'pn_Nuñez',
#  'pn_Once',
#  'pn_Palermo',
#  'pn_Palermo Chico',
#  'pn_Palermo Hollywood',
#  'pn_Palermo Soho',
#  'pn_Palermo Viejo',
#  'pn_Parque Avellaneda',
#  'pn_Parque Centenario',
#  'pn_Parque Chacabuco',
#  'pn_Parque Chas',
#  'pn_Parque Patricios',
#  'pn_Paternal',
#  'pn_Pompeya',
#  'pn_Puerto Madero',
#  'pn_Recoleta',
#  'pn_Retiro',
#  'pn_Saavedra',
#  'pn_San Cristobal',
#  'pn_San Nicolás',
#  'pn_San Telmo',
#  'pn_Tribunales',
#  'pn_Velez Sarsfield',
#  'pn_Versalles',
#  'pn_Villa Crespo',
#  'pn_Villa Devoto',
#  'pn_Villa General Mitre',
#  'pn_Villa Lugano',
#  'pn_Villa Luro',
#  'pn_Villa Ortuzar',
#  'pn_Villa Pueyrredón',
#  'pn_Villa Real',
#  'pn_Villa Riachuelo',
#  'pn_Villa Santa Rita',
#  'pn_Villa Soldati',
#  'pn_Villa Urquiza',
#  'pn_Villa del Parque']

# %%
data.shape
# Out:
# (29380, 103)

# %%
def remove_outlier(df_in, qt1, qt3, iqrout, col_name, mask1, var1, mask2=None, var2=None):
    '''
    Calculo de outliers

    Parameters
    ----------
    df_in : dataFrame
        dataFrame utilizado para extraer variables de filtro y mascaras.
    qt1, qt3: float
        Cuantil inferior y superior (0 a 1).
    iqrout: float
        Margen exterior a iqr (1.5 o 3 recomendado)
    var1, var2: str
        Nombre de columnas de dataFrame ingresado como parametro para aplicar filtro sobre los datos.
    mask1, mask2: str
        Valores para utilizar con las columnas de filtro para generar mascaras booleanas.
    col_name: str
        Variable a aplicar los outliers.
    
    Output
    ------
    dataFrame filtrado por parametros con los outliers aplicados.

    Example
    ----------
    remove_outlier(data, 0.25, 0.75, 1.5, 'price_usd_per_m2', 'Belgrano', 'place_name', 'PH', 'property_type')
    
    '''
    
    if (mask2 is None and var2 is not None) | (mask2 is not None and var2 is None):
        return 'you must set second mask with second variable'
    elif mask2 is None and var2 is None:
        var_mask = df_in[var1] == mask1
    else:
        var_mask = (df_in[var1] == mask1) & (df_in[var2] == mask2)
        
    q1 = df_in.loc[var_mask, col_name].quantile(qt1)
    q3 = df_in.loc[var_mask, col_name].quantile(qt3)
    
    iqr = q3-q1 #Interquartile range
    
    fence_low  = q1-iqrout*iqr
    fence_high = q3+iqrout*iqr
    
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high) & var_mask]
    
    return df_out

# %%
df_final = pd.DataFrame()
place_name_list = data.place_name.unique()
prop_type_list = data.property_type.unique()
for pn in place_name_list:
    for pt in prop_type_list:
        df_temp = remove_outlier(data, 0.25, 0.75, 1.5, 'price_usd_per_m2', pn, 'place_name', pt, 'property_type')
        df_final = df_final.append(df_temp)

# %%
data = df_final

# %%
df_final = pd.DataFrame()
place_name_list = data.place_name.unique()
prop_type_list = data.property_type.unique()
for pn in place_name_list:
    for pt in prop_type_list:
        df_temp = remove_outlier(data, 0.25, 0.75, 1.5, 'surface_total_in_m2', pn, 'place_name', pt, 'property_type')
        df_final = df_final.append(df_temp)

# %%
data = df_final

# %%
data.shape
# Out:
# (19824, 103)

# %%
ver = data.groupby(['place_name','property_type']).agg({'price_usd_per_m2':  ['max']})

ver.sort_values(by = [('price_usd_per_m2', 'max')], ascending=False)
# Out:
#                                price_usd_per_m2
#                                             max
# place_name       property_type
# Boedo            apartment             34608.00
# San Cristobal    apartment             26241.64
# Boedo            house                 20784.21
# Puerto Madero    apartment              9000.00
# Palermo          store                  8900.00
# ...                                         ...
# Villa Real       house                  1056.91
# Pompeya          PH                     1022.73
#                  house                   972.22
# Villa Soldati    store                   775.69
# Parque Chacabuco store                   722.54
#
# [213 rows x 1 columns]

# %%
# Boedo Departamento
mask_place_name = data.place_name == 'Boedo'
mask_property_type = data.property_type == 'apartment'
data_Belgrano = data.loc[mask_place_name&mask_property_type]
print ("Q",data_Belgrano.place_name.value_counts())
plt.boxplot(data_Belgrano["price_usd_per_m2"], vert = False)
plt.show
# Out:
# Q Boedo    584
# Name: place_name, dtype: int64
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df_final = pd.DataFrame()
mask_place_name = data.place_name == 'Boedo'
mask_property_type = data.property_type == 'apartment'
place_name_list = data.loc[mask_place_name&mask_property_type].place_name.unique()
prop_type_list =  data.loc[mask_place_name&mask_property_type].property_type.unique()
for pn in place_name_list:
    for pt in prop_type_list:
        df_temp = remove_outlier(data, 0.25, 0.75, 1.5, 'surface_total_in_m2', pn, 'place_name', pt, 'property_type')
        df_final = df_final.append(df_temp)

# %%
mask_place_name = df_final.place_name == 'Boedo'
mask_property_type = df_final.property_type == 'apartment'
data_Belgrano = df_final.loc[mask_place_name&mask_property_type]
print ("Q",data_Belgrano.place_name.value_counts())
plt.boxplot(data_Belgrano["price_usd_per_m2"], vert = False)
plt.show
# Out:
# Q Boedo    437
# Name: place_name, dtype: int64
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df_final1 = pd.DataFrame()
mask_precio_max = df_final.price_usd_per_m2 < 3500
mask_place_name = df_final.place_name == 'Boedo'
mask_property_type = df_final.property_type == 'apartment'
place_name_list = df_final.loc[mask_place_name&mask_property_type].place_name.unique()
prop_type_list =  df_final.loc[mask_place_name&mask_property_type].property_type.unique()
for pn in place_name_list:
    for pt in prop_type_list:
        df_temp = remove_outlier(df_final.loc[mask_precio_max], 0.10, 0.90, 1.5, 'surface_total_in_m2', pn, 'place_name', pt, 'property_type')
        df_final1 = df_final1.append(df_temp)

# %%
data_Belgrano = df_final1
print ("Q",data_Belgrano.place_name.value_counts())
plt.boxplot(data_Belgrano["price_usd_per_m2"], vert = False)
plt.show
# Out:
# Q Boedo    139
# Name: place_name, dtype: int64
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ver = df_final1.loc[:,['price_usd_per_m2','Id_caso']]

ver.sort_values(by = [('price_usd_per_m2')], ascending=False)
# Out:
#        price_usd_per_m2  Id_caso
# 25368           2843.99   105362
# 25359           2708.30   105319
# 25354           2619.65   105287
# 25352           2602.63   105276
# 25350           2511.50   105262
# ...                 ...      ...
# 5611            1106.67    25506
# 5608            1106.67    25503
# 5603            1106.67    25498
# 5597            1106.67    25492
# 5636            1106.67    25535
#
# [139 rows x 2 columns]

# %%
# borro todos los de Boedo / Departamento
mask_place_name = data.place_name == 'Boedo'
mask_property_type = data.property_type == 'apartment'
data = data.drop(data.loc[mask_place_name&mask_property_type].index)

# %%
# append todos los de Boedo / Departamento nuevos (sin outliers)
data = data.append(df_final1)

# %%
# valido
mask_place_name = data.place_name == 'Boedo'
mask_property_type = data.property_type == 'apartment'
data.loc[mask_place_name&mask_property_type]
# Out:
#        Id_caso property_type            place_with_parent_names country_name  \
# 1028      6482     apartment  |Argentina|Capital Federal|Boedo|    Argentina
# 2536     12682     apartment  |Argentina|Capital Federal|Boedo|    Argentina
# 5597     25492     apartment  |Argentina|Capital Federal|Boedo|    Argentina
# 5603     25498     apartment  |Argentina|Capital Federal|Boedo|    Argentina
# 5608     25503     apartment  |Argentina|Capital Federal|Boedo|    Argentina
# ...        ...           ...                                ...          ...
# 25352   105276     apartment  |Argentina|Capital Federal|Boedo|    Argentina
# 25354   105287     apartment  |Argentina|Capital Federal|Boedo|    Argentina
# 25359   105319     apartment  |Argentina|Capital Federal|Boedo|    Argentina
# 25368   105362     apartment  |Argentina|Capital Federal|Boedo|    Argentina
# 25379   105486     apartment  |Argentina|Capital Federal|Boedo|    Argentina
#
#             state_name                        lat-lon        lat        lon  \
# 1028   Capital Federal        -34.6234762,-58.4121858 -34.623476 -58.412186
# 2536   Capital Federal                            NaN        NaN        NaN
# 5597   Capital Federal                            NaN        NaN        NaN
# 5603   Capital Federal                            NaN        NaN        NaN
# 5608   Capital Federal                            NaN        NaN        NaN
# ...                ...                            ...        ...        ...
# 25352  Capital Federal  -34.6208776148,-58.4164461837 -34.620878 -58.416446
# 25354  Capital Federal  -34.6208776148,-58.4164461837 -34.620878 -58.416446
# 25359  Capital Federal  -34.6208776148,-58.4164461837 -34.620878 -58.416446
# 25368  Capital Federal  -34.6208776148,-58.4164461837 -34.620878 -58.416446
# 25379  Capital Federal  -34.6241096332,-58.4136098022 -34.624110 -58.413610
#
#            price currency  ...  pn_Villa Lugano  pn_Villa Luro  \
# 1028     75000.0      USD  ...                0              0
# 2536     73000.0      USD  ...                0              0
# 5597     33200.0      USD  ...                0              0
# 5603     33200.0      USD  ...                0              0
# 5608     33200.0      USD  ...                0              0
# ...          ...      ...  ...              ...            ...
# 25352  1485000.0      ARS  ...                0              0
# 25354  1448000.0      ARS  ...                0              0
# 25359  1497000.0      ARS  ...                0              0
# 25368  1572000.0      ARS  ...                0              0
# 25379    69000.0      USD  ...                0              0
#
#        pn_Villa Ortuzar  pn_Villa Pueyrredón  pn_Villa Real  \
# 1028                  0                    0              0
# 2536                  0                    0              0
# 5597                  0                    0              0
# 5603                  0                    0              0
# 5608                  0                    0              0
# ...                 ...                  ...            ...
# 25352                 0                    0              0
# 25354                 0                    0              0
# 25359                 0                    0              0
# 25368                 0                    0              0
# 25379                 0                    0              0
#
#       pn_Villa Riachuelo pn_Villa Santa Rita pn_Villa Soldati  \
# 1028                   0                   0                0
# 2536                   0                   0                0
# 5597                   0                   0                0
# 5603                   0                   0                0
# 5608                   0                   0                0
# ...                  ...                 ...              ...
# 25352                  0                   0                0
# 25354                  0                   0                0
# 25359                  0                   0                0
# 25368                  0                   0                0
# 25379                  0                   0                0
#
#       pn_Villa Urquiza pn_Villa del Parque
# 1028                 0                   0
# 2536                 0                   0
# 5597                 0                   0
# 5603                 0                   0
# 5608                 0                   0
# ...                ...                 ...
# 25352                0                   0
# 25354                0                   0
# 25359                0                   0
# 25368                0                   0
# 25379                0                   0
#
# [139 rows x 103 columns]

# %%
# Boedo Casa
mask_place_name = data.place_name == 'Boedo'
mask_property_type = data.property_type == 'house'
data_Belgrano = data.loc[mask_place_name&mask_property_type]
print ("Q",data_Belgrano.place_name.value_counts())
plt.boxplot(data_Belgrano["price_usd_per_m2"], vert = False)
plt.show
# Out:
# Q Boedo    30
# Name: place_name, dtype: int64
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df_final = pd.DataFrame()
mask_place_name = data.place_name == 'Boedo'
mask_property_type = data.property_type == 'house'
place_name_list = data.loc[mask_place_name&mask_property_type].place_name.unique()
prop_type_list =  data.loc[mask_place_name&mask_property_type].property_type.unique()
for pn in place_name_list:
    for pt in prop_type_list:
        df_temp = remove_outlier(data, 0.25, 0.75, 1.5, 'surface_total_in_m2', pn, 'place_name', pt, 'property_type')
        df_final = df_final.append(df_temp)

# %%
mask_place_name = df_final.place_name == 'Boedo'
mask_property_type = df_final.property_type == 'house'
data_Belgrano = df_final.loc[mask_place_name&mask_property_type]
print ("Q",data_Belgrano.place_name.value_counts())
plt.boxplot(data_Belgrano["price_usd_per_m2"], vert = False)
plt.show
# Out:
# Q Boedo    30
# Name: place_name, dtype: int64
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ver = df_final.loc[:,['price_usd_per_m2','Id_caso']]
ver.sort_values(by = [('price_usd_per_m2')], ascending=False)
# Out:
#        price_usd_per_m2  Id_caso
# 6426           20784.21    26599
# 6404           20784.21    26555
# 6467           17906.06    26702
# 6469           17903.03    26704
# 5658           15196.67    25571
# 5651           15176.67    25562
# 5652           14520.00    25563
# 5653           14093.33    25564
# 11570           1946.15    47937
# 8478            1944.44    35735
# 14233           1892.86    57976
# 13347           1822.43    55048
# 6420            1774.19    26591
# 6450            1774.19    26634
# 3596            1649.48    17392
# 25388           1596.64   105586
# 3756            1550.39    18013
# 13471           1436.57    55281
# 27166           1423.08   113031
# 6316            1333.33    26391
# 12575           1300.00    51446
# 28887           1246.43   119494
# 6146            1233.33    26187
# 5468            1184.21    25193
# 6526            1103.45    26844
# 15              1091.27       51
# 6568            1082.61    26980
# 5194            1065.22    24532
# 3881             909.09    18524
# 5467             880.95    25192

# %%
df_final1 = pd.DataFrame()
mask_precio_max = df_final.price_usd_per_m2 < 10000
mask_place_name = df_final.place_name == 'Boedo'
mask_property_type = df_final.property_type == 'house'
place_name_list = df_final.loc[mask_place_name&mask_property_type].place_name.unique()
prop_type_list =  df_final.loc[mask_place_name&mask_property_type].property_type.unique()
for pn in place_name_list:
    for pt in prop_type_list:
        df_temp = remove_outlier(df_final.loc[mask_precio_max], 0.10, 0.90, 1.5, 'surface_total_in_m2', pn, 'place_name', pt, 'property_type')
        df_final1 = df_final1.append(df_temp)

# %%
data_Belgrano = df_final1
print ("Q",data_Belgrano.place_name.value_counts())
plt.boxplot(data_Belgrano["price_usd_per_m2"], vert = False)
plt.show
# Out:
# Q Boedo    22
# Name: place_name, dtype: int64
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ver = df_final1.loc[:,['price_usd_per_m2','Id_caso']]
ver.sort_values(by = [('price_usd_per_m2')], ascending=False)
# Out:
#        price_usd_per_m2  Id_caso
# 11570           1946.15    47937
# 8478            1944.44    35735
# 14233           1892.86    57976
# 13347           1822.43    55048
# 6420            1774.19    26591
# 6450            1774.19    26634
# 3596            1649.48    17392
# 25388           1596.64   105586
# 3756            1550.39    18013
# 13471           1436.57    55281
# 27166           1423.08   113031
# 6316            1333.33    26391
# 12575           1300.00    51446
# 28887           1246.43   119494
# 6146            1233.33    26187
# 5468            1184.21    25193
# 6526            1103.45    26844
# 15              1091.27       51
# 6568            1082.61    26980
# 5194            1065.22    24532
# 3881             909.09    18524
# 5467             880.95    25192

# %%
# borro todos los de Boedo / Casa
mask_place_name = data.place_name == 'Boedo'
mask_property_type = data.property_type == 'house'
data = data.drop(data.loc[mask_place_name&mask_property_type].index)

# %%
# append todos los de Boedo / Casa nuevos (sin outliers)
data = data.append(df_final1)

# %%
# valido
mask_place_name = data.place_name == 'Boedo'
mask_property_type = data.property_type == 'house'
data.loc[mask_place_name&mask_property_type]
# Out:
#        Id_caso property_type            place_with_parent_names country_name  \
# 15          51         house  |Argentina|Capital Federal|Boedo|    Argentina
# 3596     17392         house  |Argentina|Capital Federal|Boedo|    Argentina
# 3756     18013         house  |Argentina|Capital Federal|Boedo|    Argentina
# 3881     18524         house  |Argentina|Capital Federal|Boedo|    Argentina
# 5194     24532         house  |Argentina|Capital Federal|Boedo|    Argentina
# 5467     25192         house  |Argentina|Capital Federal|Boedo|    Argentina
# 5468     25193         house  |Argentina|Capital Federal|Boedo|    Argentina
# 6146     26187         house  |Argentina|Capital Federal|Boedo|    Argentina
# 6316     26391         house  |Argentina|Capital Federal|Boedo|    Argentina
# 6420     26591         house  |Argentina|Capital Federal|Boedo|    Argentina
# 6450     26634         house  |Argentina|Capital Federal|Boedo|    Argentina
# 6526     26844         house  |Argentina|Capital Federal|Boedo|    Argentina
# 6568     26980         house  |Argentina|Capital Federal|Boedo|    Argentina
# 8478     35735         house  |Argentina|Capital Federal|Boedo|    Argentina
# 11570    47937         house  |Argentina|Capital Federal|Boedo|    Argentina
# 12575    51446         house  |Argentina|Capital Federal|Boedo|    Argentina
# 13347    55048         house  |Argentina|Capital Federal|Boedo|    Argentina
# 13471    55281         house  |Argentina|Capital Federal|Boedo|    Argentina
# 14233    57976         house  |Argentina|Capital Federal|Boedo|    Argentina
# 25388   105586         house  |Argentina|Capital Federal|Boedo|    Argentina
# 27166   113031         house  |Argentina|Capital Federal|Boedo|    Argentina
# 28887   119494         house  |Argentina|Capital Federal|Boedo|    Argentina
#
#             state_name                       lat-lon        lat        lon  \
# 15     Capital Federal       -34.6363209,-58.4107019 -34.636321 -58.410702
# 3596   Capital Federal        -34.620767,-58.4141356 -34.620767 -58.414136
# 3756   Capital Federal       -34.6328351,-58.4144969 -34.632835 -58.414497
# 3881   Capital Federal       -34.6223456,-58.4229163 -34.622346 -58.422916
# 5194   Capital Federal       -34.6292035,-58.4118558 -34.629203 -58.411856
# 5467   Capital Federal       -34.6342606,-58.4178509 -34.634261 -58.417851
# 5468   Capital Federal       -34.6314763,-58.4165521 -34.631476 -58.416552
# 6146   Capital Federal                           NaN        NaN        NaN
# 6316   Capital Federal                           NaN        NaN        NaN
# 6420   Capital Federal       -34.6209899,-58.4165467 -34.620990 -58.416547
# 6450   Capital Federal       -34.6209899,-58.4165467 -34.620990 -58.416547
# 6526   Capital Federal       -34.6343037,-58.4178477 -34.634304 -58.417848
# 6568   Capital Federal       -34.6292035,-58.4118558 -34.629203 -58.411856
# 8478   Capital Federal       -34.6372914,-58.4154267 -34.637291 -58.415427
# 11570  Capital Federal       -34.6344635,-58.4210676 -34.634464 -58.421068
# 12575  Capital Federal       -34.6330564,-58.4145004 -34.633056 -58.414500
# 13347  Capital Federal       -34.6323818,-58.4245056 -34.632382 -58.424506
# 13471  Capital Federal       -34.6299072,-58.4148216 -34.629907 -58.414822
# 14233  Capital Federal        -34.6332063,-58.420536 -34.633206 -58.420536
# 25388  Capital Federal  -34.6294606955,-58.420641094 -34.629461 -58.420641
# 27166  Capital Federal       -34.6287772,-58.4124725 -34.628777 -58.412472
# 28887  Capital Federal       -34.6317302,-58.4191998 -34.631730 -58.419200
#
#           price currency  ...  pn_Villa Lugano  pn_Villa Luro  \
# 15     550000.0      USD  ...                0              0
# 3596   800000.0      USD  ...                0              0
# 3756   400000.0      USD  ...                0              0
# 3881   300000.0      USD  ...                0              0
# 5194   245000.0      USD  ...                0              0
# 5467   370000.0      USD  ...                0              0
# 5468   450000.0      USD  ...                0              0
# 6146    37000.0      USD  ...                0              0
# 6316    40000.0      USD  ...                0              0
# 6420    55000.0      USD  ...                0              0
# 6450    55000.0      USD  ...                0              0
# 6526   320000.0      USD  ...                0              0
# 6568   249000.0      USD  ...                0              0
# 8478   350000.0      USD  ...                0              0
# 11570  253000.0      USD  ...                0              0
# 12575  650000.0      USD  ...                0              0
# 13347  390000.0      USD  ...                0              0
# 13471  385000.0      USD  ...                0              0
# 14233  265000.0      USD  ...                0              0
# 25388  380000.0      USD  ...                0              0
# 27166  185000.0      USD  ...                0              0
# 28887  349000.0      USD  ...                0              0
#
#        pn_Villa Ortuzar  pn_Villa Pueyrredón  pn_Villa Real  \
# 15                    0                    0              0
# 3596                  0                    0              0
# 3756                  0                    0              0
# 3881                  0                    0              0
# 5194                  0                    0              0
# 5467                  0                    0              0
# 5468                  0                    0              0
# 6146                  0                    0              0
# 6316                  0                    0              0
# 6420                  0                    0              0
# 6450                  0                    0              0
# 6526                  0                    0              0
# 6568                  0                    0              0
# 8478                  0                    0              0
# 11570                 0                    0              0
# 12575                 0                    0              0
# 13347                 0                    0              0
# 13471                 0                    0              0
# 14233                 0                    0              0
# 25388                 0                    0              0
# 27166                 0                    0              0
# 28887                 0                    0              0
#
#       pn_Villa Riachuelo pn_Villa Santa Rita pn_Villa Soldati  \
# 15                     0                   0                0
# 3596                   0                   0                0
# 3756                   0                   0                0
# 3881                   0                   0                0
# 5194                   0                   0                0
# 5467                   0                   0                0
# 5468                   0                   0                0
# 6146                   0                   0                0
# 6316                   0                   0                0
# 6420                   0                   0                0
# 6450                   0                   0                0
# 6526                   0                   0                0
# 6568                   0                   0                0
# 8478                   0                   0                0
# 11570                  0                   0                0
# 12575                  0                   0                0
# 13347                  0                   0                0
# 13471                  0                   0                0
# 14233                  0                   0                0
# 25388                  0                   0                0
# 27166                  0                   0                0
# 28887                  0                   0                0
#
#       pn_Villa Urquiza pn_Villa del Parque
# 15                   0                   0
# 3596                 0                   0
# 3756                 0                   0
# 3881                 0                   0
# 5194                 0                   0
# 5467                 0                   0
# 5468                 0                   0
# 6146                 0                   0
# 6316                 0                   0
# 6420                 0                   0
# 6450                 0                   0
# 6526                 0                   0
# 6568                 0                   0
# 8478                 0                   0
# 11570                0                   0
# 12575                0                   0
# 13347                0                   0
# 13471                0                   0
# 14233                0                   0
# 25388                0                   0
# 27166                0                   0
# 28887                0                   0
#
# [22 rows x 103 columns]

# %%
# San Cristobal Departamento
mask_place_name = data.place_name == 'San Cristobal'
mask_property_type = data.property_type == 'apartment'
data_Belgrano = data.loc[mask_place_name&mask_property_type]
print ("Q",data_Belgrano.place_name.value_counts())
plt.boxplot(data_Belgrano["price_usd_per_m2"], vert = False)
plt.show
# Out:
# Q San Cristobal    328
# Name: place_name, dtype: int64
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
df_final = pd.DataFrame()
mask_place_name = data.place_name == 'San Cristobal'
mask_property_type = data.property_type == 'apartment'
place_name_list = data.loc[mask_place_name&mask_property_type].place_name.unique()
prop_type_list =  data.loc[mask_place_name&mask_property_type].property_type.unique()
for pn in place_name_list:
    for pt in prop_type_list:
        df_temp = remove_outlier(data, 0.25, 0.75, 1.5, 'surface_total_in_m2', pn, 'place_name', pt, 'property_type')
        df_final = df_final.append(df_temp)

# %%
mask_place_name = df_final.place_name == 'San Cristobal'
mask_property_type = df_final.property_type == 'apartment'
data_Belgrano = df_final.loc[mask_place_name&mask_property_type]
print ("Q",data_Belgrano.place_name.value_counts())
plt.boxplot(data_Belgrano["price_usd_per_m2"], vert = False)
plt.show
# Out:
# Q San Cristobal    287
# Name: place_name, dtype: int64
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ver = df_final.loc[:,['price_usd_per_m2','Id_caso']]
ver.sort_values(by = [('price_usd_per_m2')], ascending=False)
# Out:
#        price_usd_per_m2  Id_caso
# 6320           26241.64    26396
# 6274           26136.36    26339
# 6214           26018.97    26270
# 6232           25991.55    26291
# 6125           25967.09    26161
# ...                 ...      ...
# 23124           1600.00    92510
# 23133           1600.00    92542
# 16168           1476.74    64567
# 25403           1325.58   105745
# 10248           1117.82    42524
#
# [287 rows x 2 columns]

# %%
# armamos un data con los nulos de precio y solo algunas columnas
precio_nulo = data.price_usd_per_m2.isnull()
x = data.loc[precio_nulo,["Id_caso", "place_name", "price_usd_per_m2"]]
x.set_index("Id_caso", inplace = True)

# %%
df_final1 = pd.DataFrame()
mask_precio_max = df_final.price_usd_per_m2 < 3500
mask_place_name = df_final.place_name == 'San Cristobal'
mask_property_type = df_final.property_type == 'apartment'
place_name_list = df_final.loc[mask_place_name&mask_property_type].place_name.unique()
prop_type_list =  df_final.loc[mask_place_name&mask_property_type].property_type.unique()
for pn in place_name_list:
    for pt in prop_type_list:
        df_temp = remove_outlier(df_final.loc[mask_precio_max], 0.10, 0.90, 1.5, 'surface_total_in_m2', pn, 'place_name', pt, 'property_type')
        df_final1 = df_final1.append(df_temp)

# %%
data_Belgrano = df_final1
print ("Q",data_Belgrano.place_name.value_counts())
plt.boxplot(data_Belgrano["price_usd_per_m2"], vert = False)
plt.show
# Out:
# Q San Cristobal    76
# Name: place_name, dtype: int64
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ver = df_final1.loc[:,['price_usd_per_m2','Id_caso']]
ver.sort_values(by = [('price_usd_per_m2')], ascending=False)
# Out:
#        price_usd_per_m2  Id_caso
# 27626           3142.86   114468
# 10829           3125.00    45002
# 19629           3121.95    79116
# 5729            2995.00    25660
# 5757            2840.00    25691
# ...                 ...      ...
# 23124           1600.00    92510
# 23133           1600.00    92542
# 16168           1476.74    64567
# 25403           1325.58   105745
# 10248           1117.82    42524
#
# [76 rows x 2 columns]

# %%
# borro todos los de San Cristobal / Departamento
mask_place_name = data.place_name == 'San Cristobal'
mask_property_type = data.property_type == 'apartment'
data = data.drop(data.loc[mask_place_name&mask_property_type].index)

# %%
# append todos los de San Cristobal / Departamento nuevos (sin outliers)
data = data.append(df_final1)

# %%
# valido
mask_place_name = data.place_name == 'San Cristobal'
mask_property_type = data.property_type == 'apartment'
data.loc[mask_place_name&mask_property_type]
# Out:
#        Id_caso property_type                    place_with_parent_names  \
# 1518      8184     apartment  |Argentina|Capital Federal|San Cristobal|
# 1576      8398     apartment  |Argentina|Capital Federal|San Cristobal|
# 2092     10515     apartment  |Argentina|Capital Federal|San Cristobal|
# 2505     12396     apartment  |Argentina|Capital Federal|San Cristobal|
# 3047     15005     apartment  |Argentina|Capital Federal|San Cristobal|
# ...        ...           ...                                        ...
# 26257   110344     apartment  |Argentina|Capital Federal|San Cristobal|
# 26380   110471     apartment  |Argentina|Capital Federal|San Cristobal|
# 27626   114468     apartment  |Argentina|Capital Federal|San Cristobal|
# 27778   116493     apartment  |Argentina|Capital Federal|San Cristobal|
# 27854   116720     apartment  |Argentina|Capital Federal|San Cristobal|
#
#       country_name       state_name                       lat-lon        lat  \
# 1518     Argentina  Capital Federal       -34.6244262,-58.3973636 -34.624426
# 1576     Argentina  Capital Federal  -34.620594457,-58.3964623778 -34.620594
# 2092     Argentina  Capital Federal       -34.6244262,-58.3973636 -34.624426
# 2505     Argentina  Capital Federal       -34.6197835,-58.4031237 -34.619784
# 3047     Argentina  Capital Federal       -34.6244262,-58.3973636 -34.624426
# ...            ...              ...                           ...        ...
# 26257    Argentina  Capital Federal       -34.6298632,-58.4098679 -34.629863
# 26380    Argentina  Capital Federal       -34.6244262,-58.3973636 -34.624426
# 27626    Argentina  Capital Federal       -34.6244262,-58.3973636 -34.624426
# 27778    Argentina  Capital Federal       -34.6182824,-58.3945071 -34.618282
# 27854    Argentina  Capital Federal       -34.6244126,-58.4057879 -34.624413
#
#              lon     price currency  ...  pn_Villa Lugano  pn_Villa Luro  \
# 1518  -58.397364   71000.0      USD  ...                0              0
# 1576  -58.396462   61500.0      USD  ...                0              0
# 2092  -58.397364   76000.0      USD  ...                0              0
# 2505  -58.403124   68000.0      USD  ...                0              0
# 3047  -58.397364   75000.0      USD  ...                0              0
# ...          ...       ...      ...  ...              ...            ...
# 26257 -58.409868   67000.0      USD  ...                0              0
# 26380 -58.397364   78000.0      USD  ...                0              0
# 27626 -58.397364  110000.0      USD  ...                0              0
# 27778 -58.394507  105000.0      USD  ...                0              0
# 27854 -58.405788   79500.0      USD  ...                0              0
#
#        pn_Villa Ortuzar  pn_Villa Pueyrredón  pn_Villa Real  \
# 1518                  0                    0              0
# 1576                  0                    0              0
# 2092                  0                    0              0
# 2505                  0                    0              0
# 3047                  0                    0              0
# ...                 ...                  ...            ...
# 26257                 0                    0              0
# 26380                 0                    0              0
# 27626                 0                    0              0
# 27778                 0                    0              0
# 27854                 0                    0              0
#
#       pn_Villa Riachuelo pn_Villa Santa Rita pn_Villa Soldati  \
# 1518                   0                   0                0
# 1576                   0                   0                0
# 2092                   0                   0                0
# 2505                   0                   0                0
# 3047                   0                   0                0
# ...                  ...                 ...              ...
# 26257                  0                   0                0
# 26380                  0                   0                0
# 27626                  0                   0                0
# 27778                  0                   0                0
# 27854                  0                   0                0
#
#       pn_Villa Urquiza pn_Villa del Parque
# 1518                 0                   0
# 1576                 0                   0
# 2092                 0                   0
# 2505                 0                   0
# 3047                 0                   0
# ...                ...                 ...
# 26257                0                   0
# 26380                0                   0
# 27626                0                   0
# 27778                0                   0
# 27854                0                   0
#
# [76 rows x 103 columns]

# %%
#+++++++++++++++++++++++++++++++
#validacion general
#++++++++++++++++++++++++++++++++

ver = data.groupby(['place_name','property_type']).agg({'price_usd_per_m2':  ['max']})
ver.sort_values(by = [('price_usd_per_m2', 'max')], ascending=False)
# Out:
#                                price_usd_per_m2
#                                             max
# place_name       property_type
# Puerto Madero    apartment              9000.00
# Palermo          store                  8900.00
# Palermo Chico    store                  8536.59
# Recoleta         store                  8163.27
# Puerto Madero    store                  7857.14
# ...                                         ...
# Villa Real       house                  1056.91
# Pompeya          PH                     1022.73
#                  house                   972.22
# Villa Soldati    store                   775.69
# Parque Chacabuco store                   722.54
#
# [213 rows x 1 columns]

# %%
# mediana de precios por barrios
mediana = dict(data.groupby("place_name")["price_usd_per_m2"].median())

# %%
for v, k in mediana.items():
#     print(v, k)
    barrios_nulos = x.place_name == v
    x.loc[barrios_nulos,:] = k

# %%
# cantidad de nulos por barrios
data_porc_nulos = pd.DataFrame(x["place_name"].value_counts())
data_porc_nulos.rename(columns = {"place_name":"nulos"}, inplace = True)
data_porc_todos = pd.DataFrame(data.place_name.value_counts())
data_porc_todos
data_porc = pd.concat([data_porc_nulos, data_porc_todos], axis = 1)
data_porc["porc"] = (data_porc.nulos/data_porc.place_name * 100).round(2)
data_porc.sort_values(by = ["porc"], ascending = False)
# Out:
#                  nulos  place_name  porc
# Belgrano           NaN        1804   NaN
# Palermo            NaN        1722   NaN
# Caballito          NaN        1499   NaN
# Recoleta           NaN        1067   NaN
# Villa Urquiza      NaN         999   NaN
# ...                ...         ...   ...
# Agronomía          NaN          23   NaN
# Velez Sarsfield    NaN          22   NaN
# Parque Chas        NaN          11   NaN
# Villa Soldati      NaN           4   NaN
# Villa Riachuelo    NaN           2   NaN
#
# [61 rows x 3 columns]

# %%
# armamos df con los valores imputados para concatenar al data original
a = x.drop("place_name",axis=1)
a.rename(columns = {"price_usd_per_m2": "precio_imputado"}, inplace=True)

# %%
# seteamos índices para concatenar
data.set_index("Id_caso", inplace = True)

# %%
data
# Out:
#         property_type                    place_with_parent_names country_name  \
# Id_caso
# 0                  PH      |Argentina|Capital Federal|Mataderos|    Argentina
# 16                 PH      |Argentina|Capital Federal|Mataderos|    Argentina
# 254                PH      |Argentina|Capital Federal|Mataderos|    Argentina
# 559                PH      |Argentina|Capital Federal|Mataderos|    Argentina
# 5178               PH      |Argentina|Capital Federal|Mataderos|    Argentina
# ...               ...                                        ...          ...
# 110344      apartment  |Argentina|Capital Federal|San Cristobal|    Argentina
# 110471      apartment  |Argentina|Capital Federal|San Cristobal|    Argentina
# 114468      apartment  |Argentina|Capital Federal|San Cristobal|    Argentina
# 116493      apartment  |Argentina|Capital Federal|San Cristobal|    Argentina
# 116720      apartment  |Argentina|Capital Federal|San Cristobal|    Argentina
#
#               state_name                        lat-lon        lat        lon  \
# Id_caso
# 0        Capital Federal        -34.6618237,-58.5088387 -34.661824 -58.508839
# 16       Capital Federal  -34.6523561177,-58.5016239381 -34.652356 -58.501624
# 254      Capital Federal        -34.6572422,-58.5029706 -34.657242 -58.502971
# 559      Capital Federal        -34.6569204,-58.4897843 -34.656920 -58.489784
# 5178     Capital Federal  -34.6494154483,-58.5082290736 -34.649415 -58.508229
# ...                  ...                            ...        ...        ...
# 110344   Capital Federal        -34.6298632,-58.4098679 -34.629863 -58.409868
# 110471   Capital Federal        -34.6244262,-58.3973636 -34.624426 -58.397364
# 114468   Capital Federal        -34.6244262,-58.3973636 -34.624426 -58.397364
# 116493   Capital Federal        -34.6182824,-58.3945071 -34.618282 -58.394507
# 116720   Capital Federal        -34.6244126,-58.4057879 -34.624413 -58.405788
#
#             price currency  price_aprox_local_currency  ...  pn_Villa Lugano  \
# Id_caso                                                 ...
# 0         62000.0      USD                  1093959.00  ...                0
# 16       239000.0      USD                  4217035.50  ...                0
# 254       53000.0      USD                   935158.50  ...                0
# 559      165000.0      USD                  2911342.50  ...                0
# 5178     158000.0      USD                  2787831.00  ...                0
# ...           ...      ...                         ...  ...              ...
# 110344    67000.0      USD                  1182181.50  ...                0
# 110471    78000.0      USD                  1376271.00  ...                0
# 114468   110000.0      USD                  1940895.00  ...                0
# 116493   105000.0      USD                  1852672.50  ...                0
# 116720    79500.0      USD                  1402737.75  ...                0
#
#          pn_Villa Luro  pn_Villa Ortuzar  pn_Villa Pueyrredón pn_Villa Real  \
# Id_caso
# 0                    0                 0                    0             0
# 16                   0                 0                    0             0
# 254                  0                 0                    0             0
# 559                  0                 0                    0             0
# 5178                 0                 0                    0             0
# ...                ...               ...                  ...           ...
# 110344               0                 0                    0             0
# 110471               0                 0                    0             0
# 114468               0                 0                    0             0
# 116493               0                 0                    0             0
# 116720               0                 0                    0             0
#
#         pn_Villa Riachuelo pn_Villa Santa Rita pn_Villa Soldati  \
# Id_caso
# 0                        0                   0                0
# 16                       0                   0                0
# 254                      0                   0                0
# 559                      0                   0                0
# 5178                     0                   0                0
# ...                    ...                 ...              ...
# 110344                   0                   0                0
# 110471                   0                   0                0
# 114468                   0                   0                0
# 116493                   0                   0                0
# 116720                   0                   0                0
#
#         pn_Villa Urquiza pn_Villa del Parque
# Id_caso
# 0                      0                   0
# 16                     0                   0
# 254                    0                   0
# 559                    0                   0
# 5178                   0                   0
# ...                  ...                 ...
# 110344                 0                   0
# 110471                 0                   0
# 114468                 0                   0
# 116493                 0                   0
# 116720                 0                   0
#
# [19119 rows x 102 columns]

# %%
data_imputac = pd.concat([data, a], axis = 1)

# %%
# imputamos los nulos de mt2 totales con los valores de mt2 cubiertos y lo mismo para las columnas de precio:

super_cub_no_nulo = data.surface_covered_in_m2.notnull()
data.loc[super_cub_no_nulo, "surface_total_in_m2"] = data.loc[super_cub_no_nulo, "surface_covered_in_m2"]

# %%
# reemplazamos los valores imputados en la columna precio/mt2
# 'price_per_m2'
precios_no_nulos = data_imputac.precio_imputado.notnull()
data_imputac.loc[precios_no_nulos, "price_usd_per_m2"] = data_imputac.loc[precios_no_nulos, "precio_imputado"]

# %%
data = data_imputac

# %%
mask_caba_place_name = data.place_name != 'Capital Federal'
mask_nonulo_surface_total_in_m2 = data.surface_total_in_m2.notnull()
mask_nonulo_price_usd_per_m2 = data.price_usd_per_m2.notnull()
#mask_rooms = data.rooms > 0 
#mask_nonulo_rooms = data.rooms.notnull()

# %%
data = data.loc[mask_caba_place_name & mask_nonulo_surface_total_in_m2 & mask_nonulo_price_usd_per_m2] #& mask_nonulo_rooms & mask_rooms]

# %%
data.shape
# Out:
# (18878, 103)

# %%
list(data)
# Out:
# ['property_type',
#  'place_with_parent_names',
#  'country_name',
#  'state_name',
#  'lat-lon',
#  'lat',
#  'lon',
#  'price',
#  'currency',
#  'price_aprox_local_currency',
#  'price_aprox_usd',
#  'floor',
#  'rooms',
#  'expenses',
#  'description',
#  'title',
#  'Pais',
#  'Zona',
#  'Partido_barrio',
#  'Localidad',
#  'Obs_localidad',
#  'place_name',
#  'geonames_id',
#  'price_usd_per_m2',
#  'price_per_m2',
#  'surface_total_in_m2',
#  'surface_covered_in_m2',
#  'cochera',
#  'piscina',
#  'parrilla',
#  'baulera',
#  'balcon',
#  'terraza',
#  'jardin',
#  'lavadero',
#  'subte',
#  'seguridad',
#  'metrobus',
#  'prop_type_apartment',
#  'prop_type_house',
#  'prop_type_store',
#  'pn_Agronomía',
#  'pn_Almagro',
#  'pn_Balvanera',
#  'pn_Barracas',
#  'pn_Barrio Norte',
#  'pn_Belgrano',
#  'pn_Boca',
#  'pn_Boedo',
#  'pn_Caballito',
#  'pn_Capital Federal',
#  'pn_Catalinas',
#  'pn_Centro / Microcentro',
#  'pn_Chacarita',
#  'pn_Coghlan',
#  'pn_Colegiales',
#  'pn_Congreso',
#  'pn_Constitución',
#  'pn_Flores',
#  'pn_Floresta',
#  'pn_Las Cañitas',
#  'pn_Liniers',
#  'pn_Mataderos',
#  'pn_Monserrat',
#  'pn_Monte Castro',
#  'pn_Nuñez',
#  'pn_Once',
#  'pn_Palermo',
#  'pn_Palermo Chico',
#  'pn_Palermo Hollywood',
#  'pn_Palermo Soho',
#  'pn_Palermo Viejo',
#  'pn_Parque Avellaneda',
#  'pn_Parque Centenario',
#  'pn_Parque Chacabuco',
#  'pn_Parque Chas',
#  'pn_Parque Patricios',
#  'pn_Paternal',
#  'pn_Pompeya',
#  'pn_Puerto Madero',
#  'pn_Recoleta',
#  'pn_Retiro',
#  'pn_Saavedra',
#  'pn_San Cristobal',
#  'pn_San Nicolás',
#  'pn_San Telmo',
#  'pn_Tribunales',
#  'pn_Velez Sarsfield',
#  'pn_Versalles',
#  'pn_Villa Crespo',
#  'pn_Villa Devoto',
#  'pn_Villa General Mitre',
#  'pn_Villa Lugano',
#  'pn_Villa Luro',
#  'pn_Villa Ortuzar',
#  'pn_Villa Pueyrredón',
#  'pn_Villa Real',
#  'pn_Villa Riachuelo',
#  'pn_Villa Santa Rita',
#  'pn_Villa Soldati',
#  'pn_Villa Urquiza',
#  'pn_Villa del Parque',
#  'precio_imputado']

# %%
erase_columns = [ 'place_with_parent_names', 'country_name', 'state_name', 'lat-lon',
 'lat', 'lon', 'price', 'currency', 'price_aprox_local_currency', 'price_aprox_usd', 'floor', 'expenses', 'description',
 'title', 'Pais', 'Zona', 'Partido_barrio', 'Localidad', 'Obs_localidad', 'geonames_id', 'price_per_m2', 'surface_covered_in_m2',
 'pn_Capital Federal','pn_Villa Riachuelo']

# %%
data = data.drop(data[erase_columns], axis=1)

# %%
list(data)
# Out:
# ['property_type',
#  'rooms',
#  'place_name',
#  'price_usd_per_m2',
#  'surface_total_in_m2',
#  'cochera',
#  'piscina',
#  'parrilla',
#  'baulera',
#  'balcon',
#  'terraza',
#  'jardin',
#  'lavadero',
#  'subte',
#  'seguridad',
#  'metrobus',
#  'prop_type_apartment',
#  'prop_type_house',
#  'prop_type_store',
#  'pn_Agronomía',
#  'pn_Almagro',
#  'pn_Balvanera',
#  'pn_Barracas',
#  'pn_Barrio Norte',
#  'pn_Belgrano',
#  'pn_Boca',
#  'pn_Boedo',
#  'pn_Caballito',
#  'pn_Catalinas',
#  'pn_Centro / Microcentro',
#  'pn_Chacarita',
#  'pn_Coghlan',
#  'pn_Colegiales',
#  'pn_Congreso',
#  'pn_Constitución',
#  'pn_Flores',
#  'pn_Floresta',
#  'pn_Las Cañitas',
#  'pn_Liniers',
#  'pn_Mataderos',
#  'pn_Monserrat',
#  'pn_Monte Castro',
#  'pn_Nuñez',
#  'pn_Once',
#  'pn_Palermo',
#  'pn_Palermo Chico',
#  'pn_Palermo Hollywood',
#  'pn_Palermo Soho',
#  'pn_Palermo Viejo',
#  'pn_Parque Avellaneda',
#  'pn_Parque Centenario',
#  'pn_Parque Chacabuco',
#  'pn_Parque Chas',
#  'pn_Parque Patricios',
#  'pn_Paternal',
#  'pn_Pompeya',
#  'pn_Puerto Madero',
#  'pn_Recoleta',
#  'pn_Retiro',
#  'pn_Saavedra',
#  'pn_San Cristobal',
#  'pn_San Nicolás',
#  'pn_San Telmo',
#  'pn_Tribunales',
#  'pn_Velez Sarsfield',
#  'pn_Versalles',
#  'pn_Villa Crespo',
#  'pn_Villa Devoto',
#  'pn_Villa General Mitre',
#  'pn_Villa Lugano',
#  'pn_Villa Luro',
#  'pn_Villa Ortuzar',
#  'pn_Villa Pueyrredón',
#  'pn_Villa Real',
#  'pn_Villa Santa Rita',
#  'pn_Villa Soldati',
#  'pn_Villa Urquiza',
#  'pn_Villa del Parque',
#  'precio_imputado']

# %%
data.corr()
# Out:
#                         rooms  price_usd_per_m2  surface_total_in_m2  \
# rooms                1.000000         -0.001649             0.726488
# price_usd_per_m2    -0.001649          1.000000            -0.063064
# surface_total_in_m2  0.726488         -0.063064             1.000000
# cochera              0.037329          0.256322             0.027695
# piscina             -0.153148          0.257458            -0.016344
# ...                       ...               ...                  ...
# pn_Villa Santa Rita  0.004798         -0.025203             0.010509
# pn_Villa Soldati     0.017067         -0.026265             0.484803
# pn_Villa Urquiza    -0.045854         -0.026561            -0.032035
# pn_Villa del Parque  0.001703         -0.052896             0.003153
# precio_imputado           NaN               NaN                  NaN
#
#                       cochera   piscina  parrilla   baulera   terraza  \
# rooms                0.037329 -0.153148 -0.150272  0.210845  0.072546
# price_usd_per_m2     0.256322  0.257458  0.006202  0.138821 -0.061439
# surface_total_in_m2  0.027695 -0.016344  0.008555  0.054091  0.088627
# cochera              1.000000  0.256117  0.239079  0.285608  0.133252
# piscina              0.256117  1.000000  0.398266  0.111821  0.113337
# ...                       ...       ...       ...       ...       ...
# pn_Villa Santa Rita -0.010249 -0.009427  0.005661  0.009883  0.015259
# pn_Villa Soldati    -0.010277 -0.007928 -0.008460 -0.005984 -0.008560
# pn_Villa Urquiza     0.058620  0.000280  0.090844  0.034037  0.081959
# pn_Villa del Parque -0.027675  0.042740 -0.010471 -0.023329 -0.002980
# precio_imputado           NaN       NaN       NaN       NaN       NaN
#
#                        jardin  lavadero  ...  pn_Villa Lugano  pn_Villa Luro  \
# rooms                0.076486  0.386213  ...         0.043513      -0.017231
# price_usd_per_m2     0.067100 -0.050884  ...        -0.112297      -0.064345
# surface_total_in_m2  0.072292  0.121451  ...         0.022243      -0.010399
# cochera              0.055993  0.039282  ...        -0.043709       0.006057
# piscina              0.145376 -0.102809  ...        -0.036151      -0.030375
# ...                       ...       ...  ...              ...            ...
# pn_Villa Santa Rita  0.001227  0.025779  ...        -0.002851      -0.004236
# pn_Villa Soldati    -0.002727 -0.008460  ...        -0.001140      -0.001693
# pn_Villa Urquiza    -0.007672 -0.058394  ...        -0.018506      -0.027495
# pn_Villa del Parque  0.172801 -0.000721  ...        -0.009949      -0.014781
# precio_imputado           NaN       NaN  ...              NaN            NaN
#
#                      pn_Villa Ortuzar  pn_Villa Pueyrredón  pn_Villa Real  \
# rooms                       -0.005119            -0.012487       0.022170
# price_usd_per_m2            -0.016678            -0.042939      -0.040918
# surface_total_in_m2          0.043007             0.007079       0.013130
# cochera                      0.011978            -0.004061      -0.013341
# piscina                     -0.020112            -0.027054      -0.019831
# ...                               ...                  ...            ...
# pn_Villa Santa Rita         -0.002189            -0.002631      -0.001326
# pn_Villa Soldati            -0.000875            -0.001052      -0.000530
# pn_Villa Urquiza            -0.014213            -0.017076      -0.008608
# pn_Villa del Parque         -0.007640            -0.009180      -0.004627
# precio_imputado                   NaN                  NaN            NaN
#
#                      pn_Villa Santa Rita  pn_Villa Soldati  pn_Villa Urquiza  \
# rooms                           0.004798          0.017067         -0.045854
# price_usd_per_m2               -0.025203         -0.026265         -0.026561
# surface_total_in_m2             0.010509          0.484803         -0.032035
# cochera                        -0.010249         -0.010277          0.058620
# piscina                        -0.009427         -0.007928          0.000280
# ...                                  ...               ...               ...
# pn_Villa Santa Rita             1.000000         -0.000530         -0.008608
# pn_Villa Soldati               -0.000530          1.000000         -0.003441
# pn_Villa Urquiza               -0.008608         -0.003441          1.000000
# pn_Villa del Parque            -0.004627         -0.001850         -0.030038
# precio_imputado                      NaN               NaN               NaN
#
#                      pn_Villa del Parque  precio_imputado
# rooms                           0.001703              NaN
# price_usd_per_m2               -0.052896              NaN
# surface_total_in_m2             0.003153              NaN
# cochera                        -0.027675              NaN
# piscina                         0.042740              NaN
# ...                                  ...              ...
# pn_Villa Santa Rita            -0.004627              NaN
# pn_Villa Soldati               -0.001850              NaN
# pn_Villa Urquiza               -0.030038              NaN
# pn_Villa del Parque             1.000000              NaN
# precio_imputado                      NaN              NaN
#
# [76 rows x 76 columns]

# %%
sns.heatmap(data.loc[:, ['price_usd_per_m2','surface_total_in_m2','cochera',
 'piscina',
 'parrilla',
 'baulera',
 'balcon']].corr(), annot=True, vmin=-1, cmap='Blues');

# %%
sns.heatmap(data.loc[:, ['price_usd_per_m2',
                         'terraza',
 'jardin',
 'lavadero',
 'subte',
 'seguridad',
 'metrobus']].corr(), annot=True, vmin=-1, cmap='Blues');

# %%
sns.heatmap(data.loc[:, ['price_usd_per_m2',
                         'rooms',
 'prop_type_apartment',
 'prop_type_house',
 'prop_type_store']].corr(), annot=True, vmin=-1, cmap='Blues');

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
list(data)
# Out:
# ['property_type',
#  'rooms',
#  'place_name',
#  'price_usd_per_m2',
#  'surface_total_in_m2',
#  'cochera',
#  'piscina',
#  'parrilla',
#  'baulera',
#  'balcon',
#  'terraza',
#  'jardin',
#  'lavadero',
#  'subte',
#  'seguridad',
#  'metrobus',
#  'prop_type_apartment',
#  'prop_type_house',
#  'prop_type_store',
#  'pn_Agronomía',
#  'pn_Almagro',
#  'pn_Balvanera',
#  'pn_Barracas',
#  'pn_Barrio Norte',
#  'pn_Belgrano',
#  'pn_Boca',
#  'pn_Boedo',
#  'pn_Caballito',
#  'pn_Catalinas',
#  'pn_Centro / Microcentro',
#  'pn_Chacarita',
#  'pn_Coghlan',
#  'pn_Colegiales',
#  'pn_Congreso',
#  'pn_Constitución',
#  'pn_Flores',
#  'pn_Floresta',
#  'pn_Las Cañitas',
#  'pn_Liniers',
#  'pn_Mataderos',
#  'pn_Monserrat',
#  'pn_Monte Castro',
#  'pn_Nuñez',
#  'pn_Once',
#  'pn_Palermo',
#  'pn_Palermo Chico',
#  'pn_Palermo Hollywood',
#  'pn_Palermo Soho',
#  'pn_Palermo Viejo',
#  'pn_Parque Avellaneda',
#  'pn_Parque Centenario',
#  'pn_Parque Chacabuco',
#  'pn_Parque Chas',
#  'pn_Parque Patricios',
#  'pn_Paternal',
#  'pn_Pompeya',
#  'pn_Puerto Madero',
#  'pn_Recoleta',
#  'pn_Retiro',
#  'pn_Saavedra',
#  'pn_San Cristobal',
#  'pn_San Nicolás',
#  'pn_San Telmo',
#  'pn_Tribunales',
#  'pn_Velez Sarsfield',
#  'pn_Versalles',
#  'pn_Villa Crespo',
#  'pn_Villa Devoto',
#  'pn_Villa General Mitre',
#  'pn_Villa Lugano',
#  'pn_Villa Luro',
#  'pn_Villa Ortuzar',
#  'pn_Villa Pueyrredón',
#  'pn_Villa Real',
#  'pn_Villa Santa Rita',
#  'pn_Villa Soldati',
#  'pn_Villa Urquiza',
#  'pn_Villa del Parque',
#  'precio_imputado']

# %%
data['surface_total_in_m2_x6'] = data['surface_total_in_m2']**6

# %%
model = LinearRegression(fit_intercept=True)

feature_cols = [#'rooms',
'surface_total_in_m2',
 'cochera',
 'piscina',
 'parrilla',
 'baulera',
 'balcon',
 'terraza',
 'jardin',
 'lavadero',
 'subte',
 'seguridad',
 'metrobus',
 'prop_type_apartment',
 'prop_type_house',
 'prop_type_store',
 'pn_Agronomía',
 'pn_Almagro',
 'pn_Balvanera',
 'pn_Barracas',
 'pn_Barrio Norte',
 'pn_Belgrano',
 'pn_Boca',
 'pn_Boedo',
 'pn_Caballito',
 'pn_Catalinas',
 'pn_Centro / Microcentro',
 'pn_Chacarita',
 'pn_Coghlan',
 'pn_Colegiales',
 'pn_Congreso',
 'pn_Constitución',
 'pn_Flores',
 'pn_Floresta',
 'pn_Las Cañitas',
 'pn_Liniers',
 'pn_Mataderos',
 'pn_Monserrat',
 'pn_Monte Castro',
 'pn_Nuñez',
 'pn_Once',
 'pn_Palermo',
 'pn_Palermo Chico',
 'pn_Palermo Hollywood',
 'pn_Palermo Soho',
 'pn_Palermo Viejo',
 'pn_Parque Avellaneda',
 'pn_Parque Centenario',
 'pn_Parque Chacabuco',
 'pn_Parque Chas',
 'pn_Parque Patricios',
 'pn_Paternal',
 'pn_Pompeya',
 'pn_Puerto Madero',
 'pn_Recoleta',
 'pn_Retiro',
 'pn_Saavedra',
 'pn_San Cristobal',
 'pn_San Nicolás',
 'pn_San Telmo',
 'pn_Tribunales',
 'pn_Velez Sarsfield',
 'pn_Versalles',
 'pn_Villa Crespo',
 'pn_Villa Devoto',
 'pn_Villa General Mitre',
 'pn_Villa Lugano',
 'pn_Villa Luro',
 'pn_Villa Ortuzar',
 'pn_Villa Pueyrredón',
 'pn_Villa Real',
 'pn_Villa Riachuelo',
 'pn_Villa Santa Rita',
 'pn_Villa Soldati',
 'pn_Villa Urquiza',
 'pn_Villa del Parque']
X = data[feature_cols]
y = data.price_usd_per_m2

Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, random_state=1)

scaler = StandardScaler()
scaler.fit_transform(Xtrain)

model.fit(Xtrain, ytrain)
ypred = model.predict(Xtest)
ypred_train = model.predict(Xtrain)

print ('MAE:', mean_absolute_error(ytest, ypred).round(2))
print ('MSE:', mean_squared_error(ytest, ypred).round(2))
print ('RMSE:', np.sqrt(mean_squared_error(ytest, ypred)).round(2))
print ('R2:', r2_score(ytest, ypred).round(2))
# Out:
# MAE: 428.22
# MSE: 373658.2
# RMSE: 611.28
# R2: 0.62

# %%
r2_score(ytrain, ypred_train).round(2)
# Out:
# 0.64
